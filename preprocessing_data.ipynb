# %%
import pandas as pd
from config.config import OUTPUT_CSV_FILE, CLEANED_CSV_FILE

# %%
df = pd.read_csv(OUTPUT_CSV_FILE, index_col=0) # index_col=0 for removing meaningless ID
df.drop(columns=['Binanın növü'], inplace=True)
df
# Out:
#       item_id  amount currency  \
# 0     5071639  175000      AZN
# 1     5191719  295000      AZN
# 2     5071285   54000      AZN
# 3     5221397   59000      AZN
# 4     5226347  200000      AZN
# ...       ...     ...      ...
# 9882  5152734  430000      AZN
# 9883  5219770  230000      AZN
# 9884  5229215  168000      AZN
# 9885  4531768  270000      AZN
# 9886  4740300  510000      AZN
#
#                                                location         Kateqoriya  \
# 0                  ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1     ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                          ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                    []        Yeni tikili
# 4                        ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# ...                                                 ...                ...
# 9882  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...        Yeni tikili
# 9883  ['Səməd Vurğun parkı', 'Port Baku', 'Azadlıq m...       Köhnə tikili
# 9884                       ['Abşeron r.', 'Novxanı q.']  Həyət evi/Bağ evi
# 9885            ['Elmlər Akademiyası m.', 'Yasamal r.']        Yeni tikili
# 9886                        ['Xətai r.', 'Ağ şəhər q.']        Yeni tikili
#
#       Mərtəbə    Sahə  Otaq sayı Çıxarış İpoteka   Təmir Torpaq sahəsi
# 0      5 / 15   60 m²        1.0     var     var  yoxdur           NaN
# 1     14 / 22  105 m²        2.0     var     NaN     var           NaN
# 2       6 / 6   83 m²        2.0  yoxdur     NaN  yoxdur           NaN
# 3      5 / 16   43 m²        2.0  yoxdur     NaN     var           NaN
# 4      2 / 14   90 m²        2.0     var     NaN  yoxdur           NaN
# ...       ...     ...        ...     ...     ...     ...           ...
# 9882   9 / 17  128 m²        3.0     var     NaN     var           NaN
# 9883    2 / 5   58 m²        2.0     var     NaN     var           NaN
# 9884      NaN  180 m²        4.0     var     NaN     var        24 sot
# 9885   3 / 18   86 m²        2.0     var     var  yoxdur           NaN
# 9886    3 / 7   84 m²        3.0  yoxdur     var     var           NaN
#
# [9887 rows x 12 columns]

# %%
column_mapping = {
    'item_id': 'Item_id',
    'amount': 'Amount',
    'currency': 'Currency',
    'location': 'Location',
    'Kateqoriya': 'Category',
    'Sahə': 'Area',
    'Torpaq sahəsi': 'Land_area',
    'Otaq sayı': 'Number_of_rooms',
    'Çıxarış': 'Frontage',
    'İpoteka': 'Mortgage',
    'Təmir': 'Condition',
    'Mərtəbə': 'Floor',
}

df.rename(columns=column_mapping, inplace=True)
df.columns
# Out:
# Index(['Item_id', 'Amount', 'Currency', 'Location', 'Category', 'Floor',
#        'Area', 'Number_of_rooms', 'Frontage', 'Mortgage', 'Condition',
#        'Land_area'],
#       dtype='object')

# %%
columns_to_update = ['Frontage', 'Mortgage', 'Condition']

for col in columns_to_update:
    df[col] = df[col].replace({'var': 1, 'yoxdur': 0})
    df[col] = df[col].fillna(0).astype(int)
df
# Out:
# C:\Users\Nariman\AppData\Local\Temp\ipykernel_12992\3361587275.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'var': 1, 'yoxdur': 0})
# C:\Users\Nariman\AppData\Local\Temp\ipykernel_12992\3361587275.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'var': 1, 'yoxdur': 0})
# C:\Users\Nariman\AppData\Local\Temp\ipykernel_12992\3361587275.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'var': 1, 'yoxdur': 0})
#       Item_id  Amount Currency  \
# 0     5071639  175000      AZN
# 1     5191719  295000      AZN
# 2     5071285   54000      AZN
# 3     5221397   59000      AZN
# 4     5226347  200000      AZN
# ...       ...     ...      ...
# 9882  5152734  430000      AZN
# 9883  5219770  230000      AZN
# 9884  5229215  168000      AZN
# 9885  4531768  270000      AZN
# 9886  4740300  510000      AZN
#
#                                                Location           Category  \
# 0                  ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1     ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                          ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                    []        Yeni tikili
# 4                        ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# ...                                                 ...                ...
# 9882  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...        Yeni tikili
# 9883  ['Səməd Vurğun parkı', 'Port Baku', 'Azadlıq m...       Köhnə tikili
# 9884                       ['Abşeron r.', 'Novxanı q.']  Həyət evi/Bağ evi
# 9885            ['Elmlər Akademiyası m.', 'Yasamal r.']        Yeni tikili
# 9886                        ['Xətai r.', 'Ağ şəhər q.']        Yeni tikili
#
#         Floor    Area  Number_of_rooms  Frontage  Mortgage  Condition  \
# 0      5 / 15   60 m²              1.0         1         1          0
# 1     14 / 22  105 m²              2.0         1         0          1
# 2       6 / 6   83 m²              2.0         0         0          0
# 3      5 / 16   43 m²              2.0         0         0          1
# 4      2 / 14   90 m²              2.0         1         0          0
# ...       ...     ...              ...       ...       ...        ...
# 9882   9 / 17  128 m²              3.0         1         0          1
# 9883    2 / 5   58 m²              2.0         1         0          1
# 9884      NaN  180 m²              4.0         1         0          1
# 9885   3 / 18   86 m²              2.0         1         1          0
# 9886    3 / 7   84 m²              3.0         0         1          1
#
#      Land_area
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 9882       NaN
# 9883       NaN
# 9884    24 sot
# 9885       NaN
# 9886       NaN
#
# [9887 rows x 12 columns]

# %%
df[['Current_floor', 'Total_floors']] = df['Floor'].str.split(' / ', expand=True)

df['Current_floor'] = pd.to_numeric(df['Current_floor'], errors='coerce')
df['Total_floors'] = pd.to_numeric(df['Total_floors'], errors='coerce')
df.drop(columns=['Floor'], inplace=True)

df
# Out:
#       Item_id  Amount Currency  \
# 0     5071639  175000      AZN
# 1     5191719  295000      AZN
# 2     5071285   54000      AZN
# 3     5221397   59000      AZN
# 4     5226347  200000      AZN
# ...       ...     ...      ...
# 9882  5152734  430000      AZN
# 9883  5219770  230000      AZN
# 9884  5229215  168000      AZN
# 9885  4531768  270000      AZN
# 9886  4740300  510000      AZN
#
#                                                Location           Category  \
# 0                  ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1     ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                          ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                    []        Yeni tikili
# 4                        ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# ...                                                 ...                ...
# 9882  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...        Yeni tikili
# 9883  ['Səməd Vurğun parkı', 'Port Baku', 'Azadlıq m...       Köhnə tikili
# 9884                       ['Abşeron r.', 'Novxanı q.']  Həyət evi/Bağ evi
# 9885            ['Elmlər Akademiyası m.', 'Yasamal r.']        Yeni tikili
# 9886                        ['Xətai r.', 'Ağ şəhər q.']        Yeni tikili
#
#         Area  Number_of_rooms  Frontage  Mortgage  Condition Land_area  \
# 0      60 m²              1.0         1         1          0       NaN
# 1     105 m²              2.0         1         0          1       NaN
# 2      83 m²              2.0         0         0          0       NaN
# 3      43 m²              2.0         0         0          1       NaN
# 4      90 m²              2.0         1         0          0       NaN
# ...      ...              ...       ...       ...        ...       ...
# 9882  128 m²              3.0         1         0          1       NaN
# 9883   58 m²              2.0         1         0          1       NaN
# 9884  180 m²              4.0         1         0          1    24 sot
# 9885   86 m²              2.0         1         1          0       NaN
# 9886   84 m²              3.0         0         1          1       NaN
#
#       Current_floor  Total_floors
# 0               5.0          15.0
# 1              14.0          22.0
# 2               6.0           6.0
# 3               5.0          16.0
# 4               2.0          14.0
# ...             ...           ...
# 9882            9.0          17.0
# 9883            2.0           5.0
# 9884            NaN           NaN
# 9885            3.0          18.0
# 9886            3.0           7.0
#
# [9887 rows x 13 columns]

# %%
df['Land_area'] = df['Land_area'].astype(str)

mask = df['Area'].str.contains('sot', case=False, na=False)

sot_values = df.loc[mask, 'Area']

df.loc[mask, 'Land_area'] = sot_values
df.loc[mask, 'Area'] = '0'

df['Land_area'] = df['Land_area'].replace('nan', '0').fillna('0')

df
# Out:
#       Item_id  Amount Currency  \
# 0     5071639  175000      AZN
# 1     5191719  295000      AZN
# 2     5071285   54000      AZN
# 3     5221397   59000      AZN
# 4     5226347  200000      AZN
# ...       ...     ...      ...
# 9882  5152734  430000      AZN
# 9883  5219770  230000      AZN
# 9884  5229215  168000      AZN
# 9885  4531768  270000      AZN
# 9886  4740300  510000      AZN
#
#                                                Location           Category  \
# 0                  ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1     ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                          ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                    []        Yeni tikili
# 4                        ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# ...                                                 ...                ...
# 9882  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...        Yeni tikili
# 9883  ['Səməd Vurğun parkı', 'Port Baku', 'Azadlıq m...       Köhnə tikili
# 9884                       ['Abşeron r.', 'Novxanı q.']  Həyət evi/Bağ evi
# 9885            ['Elmlər Akademiyası m.', 'Yasamal r.']        Yeni tikili
# 9886                        ['Xətai r.', 'Ağ şəhər q.']        Yeni tikili
#
#         Area  Number_of_rooms  Frontage  Mortgage  Condition Land_area  \
# 0      60 m²              1.0         1         1          0         0
# 1     105 m²              2.0         1         0          1         0
# 2      83 m²              2.0         0         0          0         0
# 3      43 m²              2.0         0         0          1         0
# 4      90 m²              2.0         1         0          0         0
# ...      ...              ...       ...       ...        ...       ...
# 9882  128 m²              3.0         1         0          1         0
# 9883   58 m²              2.0         1         0          1         0
# 9884  180 m²              4.0         1         0          1    24 sot
# 9885   86 m²              2.0         1         1          0         0
# 9886   84 m²              3.0         0         1          1         0
#
#       Current_floor  Total_floors
# 0               5.0          15.0
# 1              14.0          22.0
# 2               6.0           6.0
# 3               5.0          16.0
# 4               2.0          14.0
# ...             ...           ...
# 9882            9.0          17.0
# 9883            2.0           5.0
# 9884            NaN           NaN
# 9885            3.0          18.0
# 9886            3.0           7.0
#
# [9887 rows x 13 columns]

# %%
df['Number_of_rooms'] = df['Number_of_rooms'].fillna(0)
df['Current_floor'] = df['Current_floor'].fillna(0)
df['Total_floors'] = df['Total_floors'].fillna(0)
df.to_csv(CLEANED_CSV_FILE)
print(df.head(10))
print(df.describe)
# Out:
#    Item_id  Amount Currency  \
# 0  5071639  175000      AZN
# 1  5191719  295000      AZN
# 2  5071285   54000      AZN
# 3  5221397   59000      AZN
# 4  5226347  200000      AZN
# 5  5234149  176000      AZN
# 6  5049112  298000      AZN
# 7  5236410     850      AZN
# 8  3311889  950000      AZN
# 9  5210034  290000      AZN
#
#                                             Location           Category  \
# 0               ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1  ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                       ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                 []        Yeni tikili
# 4                     ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# 5  ['Neapol dairəsi', 'Əhmədli m.', 'Xətai r.', '...       Köhnə tikili
# 6  ['Elmlər Akademiyası m.', 'İncəsənət və Mədəni...        Yeni tikili
# 7  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...       Köhnə tikili
# 8                        ['Xəzər r.', 'Mərdəkan q.']  Həyət evi/Bağ evi
# 9                                       ['Xətai r.']        Yeni tikili
#
#        Area  Number_of_rooms  Frontage  Mortgage  Condition Land_area  \
# 0     60 m²              1.0         1         1          0         0
# 1    105 m²              2.0         1         0          1         0
# 2     83 m²              2.0         0         0          0         0
# 3     43 m²              2.0         0         0          1         0
# 4     90 m²              2.0         1         0          0         0
# 5     87 m²              3.0         1         1          1         0
# 6  113.7 m²              3.0         1         1          0         0
# 7    850 m²              1.0         0         0          1         0
# 8    400 m²              0.0         1         0          1    16 sot
# 9    128 m²              4.0         1         0          1         0
#
#    Current_floor  Total_floors
# 0            5.0          15.0
# 1           14.0          22.0
# 2            6.0           6.0
# 3            5.0          16.0
# 4            2.0          14.0
# 5            8.0           9.0
# 6           14.0          18.0
# 7            3.0           5.0
# 8            0.0           0.0
# 9            7.0          20.0
# <bound method NDFrame.describe of       Item_id  Amount Currency  \
# 0     5071639  175000      AZN
# 1     5191719  295000      AZN
# 2     5071285   54000      AZN
# 3     5221397   59000      AZN
# 4     5226347  200000      AZN
# ...       ...     ...      ...
# 9882  5152734  430000      AZN
# 9883  5219770  230000      AZN
# 9884  5229215  168000      AZN
# 9885  4531768  270000      AZN
# 9886  4740300  510000      AZN
#
#                                                Location           Category  \
# 0                  ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1     ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                          ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                    []        Yeni tikili
# 4                        ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# ...                                                 ...                ...
# 9882  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...        Yeni tikili
# 9883  ['Səməd Vurğun parkı', 'Port Baku', 'Azadlıq m...       Köhnə tikili
# 9884                       ['Abşeron r.', 'Novxanı q.']  Həyət evi/Bağ evi
# 9885            ['Elmlər Akademiyası m.', 'Yasamal r.']        Yeni tikili
# 9886                        ['Xətai r.', 'Ağ şəhər q.']        Yeni tikili
#
#         Area  Number_of_rooms  Frontage  Mortgage  Condition Land_area  \
# 0      60 m²              1.0         1         1          0         0
# 1     105 m²              2.0         1         0          1         0
# 2      83 m²              2.0         0         0          0         0
# 3      43 m²              2.0         0         0          1         0
# 4      90 m²              2.0         1         0          0         0
# ...      ...              ...       ...       ...        ...       ...
# 9882  128 m²              3.0         1         0          1         0
# 9883   58 m²              2.0         1         0          1         0
# 9884  180 m²              4.0         1         0          1    24 sot
# 9885   86 m²              2.0         1         1          0         0
# 9886   84 m²              3.0         0         1          1         0
#
#       Current_floor  Total_floors
# 0               5.0          15.0
# 1              14.0          22.0
# 2               6.0           6.0
# 3               5.0          16.0
# 4               2.0          14.0
# ...             ...           ...
# 9882            9.0          17.0
# 9883            2.0           5.0
# 9884            0.0           0.0
# 9885            3.0          18.0
# 9886            3.0           7.0
#
# [9887 rows x 13 columns]>
