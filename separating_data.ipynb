# %%
import pandas as pd
from config.config import CLEANED_CSV_FILE

df = pd.read_csv(CLEANED_CSV_FILE)
df
# Out:
#       Unnamed: 0  Item_id  Amount Currency  \
# 0              0  5071639  175000      AZN
# 1              1  5191719  295000      AZN
# 2              2  5071285   54000      AZN
# 3              3  5221397   59000      AZN
# 4              4  5226347  200000      AZN
# ...          ...      ...     ...      ...
# 9882        9882  5152734  430000      AZN
# 9883        9883  5219770  230000      AZN
# 9884        9884  5229215  168000      AZN
# 9885        9885  4531768  270000      AZN
# 9886        9886  4740300  510000      AZN
#
#                                                Location           Category  \
# 0                  ['Şah İsmayıl Xətai m.', 'Xətai r.']        Yeni tikili
# 1     ['ASAN Xidmət №2', 'Şah İsmayıl Xətai m.', 'Xə...        Yeni tikili
# 2                          ['Abşeron r.', 'Masazır q.']        Yeni tikili
# 3                                                    []        Yeni tikili
# 4                        ['Sabunçu r.', 'Bakıxanov q.']        Yeni tikili
# ...                                                 ...                ...
# 9882  ['ASAN Xidmət №3', 'Yasamal bazarı', 'Elmlər A...        Yeni tikili
# 9883  ['Səməd Vurğun parkı', 'Port Baku', 'Azadlıq m...       Köhnə tikili
# 9884                       ['Abşeron r.', 'Novxanı q.']  Həyət evi/Bağ evi
# 9885            ['Elmlər Akademiyası m.', 'Yasamal r.']        Yeni tikili
# 9886                        ['Xətai r.', 'Ağ şəhər q.']        Yeni tikili
#
#         Area  Number_of_rooms  Frontage  Mortgage  Condition Land_area  \
# 0      60 m²              1.0         1         1          0         0
# 1     105 m²              2.0         1         0          1         0
# 2      83 m²              2.0         0         0          0         0
# 3      43 m²              2.0         0         0          1         0
# 4      90 m²              2.0         1         0          0         0
# ...      ...              ...       ...       ...        ...       ...
# 9882  128 m²              3.0         1         0          1         0
# 9883   58 m²              2.0         1         0          1         0
# 9884  180 m²              4.0         1         0          1    24 sot
# 9885   86 m²              2.0         1         1          0         0
# 9886   84 m²              3.0         0         1          1         0
#
#       Current_floor  Total_floors
# 0               5.0          15.0
# 1              14.0          22.0
# 2               6.0           6.0
# 3               5.0          16.0
# 4               2.0          14.0
# ...             ...           ...
# 9882            9.0          17.0
# 9883            2.0           5.0
# 9884            0.0           0.0
# 9885            3.0          18.0
# 9886            3.0           7.0
#
# [9887 rows x 14 columns]

# %%
category_to_file = {
    'Yeni tikili': 'data/yeni_tikili_data.csv',
    'Torpaq': 'data/torpaq_data.csv',
    'Həyət evi/Bağ evi': 'data/heyet_evi_data.csv',
    'Köhnə tikili': 'data/kohne_tikili_data.csv',
    'Obyekt': 'data/obyekt_data.csv',
    'Ofis': 'data/ofis_data.csv',
    'Qaraj': 'data/qaraj_data.csv'
}

for category, filename in category_to_file.items():
    category_df = df[df['Category'] == category]
    if not category_df.empty:
        category_df.to_csv(filename, index=False)
        print(f"Saved {len(category_df)} records to {filename}")
    else:
        print(f"No data found for category: {category}, skipping...")
# Out:
# Saved 5258 records to data/yeni_tikili_data.csv
# Saved 475 records to data/torpaq_data.csv
# Saved 2031 records to data/heyet_evi_data.csv
# Saved 1422 records to data/kohne_tikili_data.csv
# Saved 532 records to data/obyekt_data.csv
# Saved 162 records to data/ofis_data.csv
# Saved 7 records to data/qaraj_data.csv
