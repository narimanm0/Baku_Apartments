# %%
import pandas as pd
from config.config import HEYET_CSV_FILE

df = pd.read_csv('data/heyet_evi_data.csv')
df
# Out:
#       Unnamed: 0  Item_id  Amount Currency                        Location  \
# 0             12  5138864  180000      AZN      ['Xəzər r.', 'Şüvəlan q.']
# 1             13  4542167  495000      AZN     ['Xəzər r.', 'Mərdəkan q.']
# 2             20  5121336     600      AZN  ['Neftçi bazası', 'Nəsimi r.']
# 3             27  5192789   95000      AZN    ['Sabunçu r.', 'Maştağa q.']
# 4             29  4875516    3500      AZN     ['Xəzər r.', 'Mərdəkan q.']
# ...          ...      ...     ...      ...                             ...
# 1915        7340  4852312  175000      AZN     ['Xəzər r.', 'Mərdəkan q.']
# 1916        7346  5194168  250000      AZN                              []
# 1917        7348  4707817  107000      AZN    ['Abşeron r.', 'Masazır q.']
# 1918        7353  4533346  320000      AZN     ['Xəzər r.', 'Mərdəkan q.']
# 1919        7358  5057528    5000      AZN     ['Sabunçu r.', 'Bilgəh q.']
#
#                Category    Area  Number_of_rooms  Frontage  Mortgage  \
# 0     Həyət evi/Bağ evi  150 m²              4.0         1         0
# 1     Həyət evi/Bağ evi  250 m²              5.0         1         1
# 2     Həyət evi/Bağ evi  100 m²              4.0         0         0
# 3     Həyət evi/Bağ evi  110 m²              4.0         1         0
# 4     Həyət evi/Bağ evi  280 m²              5.0         0         0
# ...                 ...     ...              ...       ...       ...
# 1915  Həyət evi/Bağ evi  120 m²              4.0         1         1
# 1916  Həyət evi/Bağ evi  150 m²              6.0         1         1
# 1917  Həyət evi/Bağ evi  180 m²              5.0         1         1
# 1918  Həyət evi/Bağ evi  200 m²              4.0         1         0
# 1919  Həyət evi/Bağ evi  600 m²              6.0         0         0
#
#       Condition Land_area  Current_floor  Total_floors
# 0             1     3 sot            0.0           0.0
# 1             1   7.2 sot            0.0           0.0
# 2             1     2 sot            0.0           0.0
# 3             1   2.2 sot            0.0           0.0
# 4             1     7 sot            0.0           0.0
# ...         ...       ...            ...           ...
# 1915          1   2.6 sot            0.0           0.0
# 1916          1   3.5 sot            0.0           0.0
# 1917          1   1.5 sot            0.0           0.0
# 1918          1     5 sot            0.0           0.0
# 1919          1    30 sot            0.0           0.0
#
# [1920 rows x 14 columns]

# %%
to_delete = ["Unnamed: 0", "Item_id", "Category", "Currency", "Current_floor", "Total_floors"]
data = df.drop(to_delete, axis=1)
data
# Out:
#       Amount                        Location    Area  Number_of_rooms  \
# 0     180000      ['Xəzər r.', 'Şüvəlan q.']  150 m²              4.0
# 1     495000     ['Xəzər r.', 'Mərdəkan q.']  250 m²              5.0
# 2        600  ['Neftçi bazası', 'Nəsimi r.']  100 m²              4.0
# 3      95000    ['Sabunçu r.', 'Maştağa q.']  110 m²              4.0
# 4       3500     ['Xəzər r.', 'Mərdəkan q.']  280 m²              5.0
# ...      ...                             ...     ...              ...
# 1915  175000     ['Xəzər r.', 'Mərdəkan q.']  120 m²              4.0
# 1916  250000                              []  150 m²              6.0
# 1917  107000    ['Abşeron r.', 'Masazır q.']  180 m²              5.0
# 1918  320000     ['Xəzər r.', 'Mərdəkan q.']  200 m²              4.0
# 1919    5000     ['Sabunçu r.', 'Bilgəh q.']  600 m²              6.0
#
#       Frontage  Mortgage  Condition Land_area
# 0            1         0          1     3 sot
# 1            1         1          1   7.2 sot
# 2            0         0          1     2 sot
# 3            1         0          1   2.2 sot
# 4            0         0          1     7 sot
# ...        ...       ...        ...       ...
# 1915         1         1          1   2.6 sot
# 1916         1         1          1   3.5 sot
# 1917         1         1          1   1.5 sot
# 1918         1         0          1     5 sot
# 1919         0         0          1    30 sot
#
# [1920 rows x 8 columns]

# %%
result = "Yes" if data['Area'].str.endswith('m²').all() else "No"
result

result = "Yes" if data['Land_area'].str.endswith('sot').all() else "No"
result
# Out:
# 'Yes'

# %%
data['Area'] = data['Area'].str.replace('m²', '', regex=False).astype(float)
data['Land_area'] = data['Land_area'].str.replace('sot', '', regex=False).astype(float)
data['Land_area'] = data['Land_area']*100 # sot to m²
data
# Out:
#       Amount                        Location   Area  Number_of_rooms  \
# 0     180000      ['Xəzər r.', 'Şüvəlan q.']  150.0              4.0
# 1     495000     ['Xəzər r.', 'Mərdəkan q.']  250.0              5.0
# 2        600  ['Neftçi bazası', 'Nəsimi r.']  100.0              4.0
# 3      95000    ['Sabunçu r.', 'Maştağa q.']  110.0              4.0
# 4       3500     ['Xəzər r.', 'Mərdəkan q.']  280.0              5.0
# ...      ...                             ...    ...              ...
# 1915  175000     ['Xəzər r.', 'Mərdəkan q.']  120.0              4.0
# 1916  250000                              []  150.0              6.0
# 1917  107000    ['Abşeron r.', 'Masazır q.']  180.0              5.0
# 1918  320000     ['Xəzər r.', 'Mərdəkan q.']  200.0              4.0
# 1919    5000     ['Sabunçu r.', 'Bilgəh q.']  600.0              6.0
#
#       Frontage  Mortgage  Condition  Land_area
# 0            1         0          1      300.0
# 1            1         1          1      720.0
# 2            0         0          1      200.0
# 3            1         0          1      220.0
# 4            0         0          1      700.0
# ...        ...       ...        ...        ...
# 1915         1         1          1      260.0
# 1916         1         1          1      350.0
# 1917         1         1          1      150.0
# 1918         1         0          1      500.0
# 1919         0         0          1     3000.0
#
# [1920 rows x 8 columns]

# %%
data.isna().any()
# Out:
# Amount             False
# Location           False
# Area               False
# Number_of_rooms    False
# Frontage           False
# Mortgage           False
# Condition          False
# Land_area          False
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt

to_numeric = ['Amount', 'Area', 'Number_of_rooms', "Land_area"] 
numeric_data = data[to_numeric]
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
data = data[(df['Amount'] > 20_000) & (df['Amount'] < 600_000)]

# %%
data['Price_per_sqm'] = data['Amount'] / data['Area']
# Out:
# C:\Users\Nariman\AppData\Local\Temp\ipykernel_6432\3397903115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Price_per_sqm'] = data['Amount'] / data['Area']

# %%
data['Location_length'] = data['Location'].str.len()
# Out:
# C:\Users\Nariman\AppData\Local\Temp\ipykernel_6432\3929028353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Location_length'] = data['Location'].str.len()

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

data['Location_str'] = data['Location'].str.join(' ').str.lower()
data
# Out:
# C:\Users\Nariman\AppData\Local\Temp\ipykernel_6432\2259878218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Location_str'] = data['Location'].str.join(' ').str.lower()
#       Amount                      Location   Area  Number_of_rooms  Frontage  \
# 0     180000    ['Xəzər r.', 'Şüvəlan q.']  150.0              4.0         1
# 1     495000   ['Xəzər r.', 'Mərdəkan q.']  250.0              5.0         1
# 3      95000  ['Sabunçu r.', 'Maştağa q.']  110.0              4.0         1
# 5     435000   ['Xəzər r.', 'Mərdəkan q.']  200.0              4.0         1
# 6     245000   ['Xəzər r.', 'Mərdəkan q.']  170.0              4.0         1
# ...      ...                           ...    ...              ...       ...
# 1913  290000     ['Səbail r.', 'Bayıl q.']  210.0              6.0         0
# 1915  175000   ['Xəzər r.', 'Mərdəkan q.']  120.0              4.0         1
# 1916  250000                            []  150.0              6.0         1
# 1917  107000  ['Abşeron r.', 'Masazır q.']  180.0              5.0         1
# 1918  320000   ['Xəzər r.', 'Mərdəkan q.']  200.0              4.0         1
#
#       Mortgage  Condition  Land_area  Price_per_sqm  Location_length  \
# 0            0          1      300.0    1200.000000               26
# 1            1          1      720.0    1980.000000               27
# 3            0          1      220.0     863.636364               28
# 5            1          1      550.0    2175.000000               27
# 6            0          1      400.0    1441.176471               27
# ...        ...        ...        ...            ...              ...
# 1913         0          1      400.0    1380.952381               25
# 1915         1          1      260.0    1458.333333               27
# 1916         1          1      350.0    1666.666667                2
# 1917         1          1      150.0     594.444444               28
# 1918         0          1      500.0    1600.000000               27
#
#                                            Location_str
# 0     [ ' x ə z ə r   r . ' ,   ' ş ü v ə l a n   q ...
# 1     [ ' x ə z ə r   r . ' ,   ' m ə r d ə k a n   ...
# 3     [ ' s a b u n ç u   r . ' ,   ' m a ş t a ğ a ...
# 5     [ ' x ə z ə r   r . ' ,   ' m ə r d ə k a n   ...
# 6     [ ' x ə z ə r   r . ' ,   ' m ə r d ə k a n   ...
# ...                                                 ...
# 1913  [ ' s ə b a i l   r . ' ,   ' b a y ı l   q . ' ]
# 1915  [ ' x ə z ə r   r . ' ,   ' m ə r d ə k a n   ...
# 1916                                                [ ]
# 1917  [ ' a b ş e r o n   r . ' ,   ' m a s a z ı r ...
# 1918  [ ' x ə z ə r   r . ' ,   ' m ə r d ə k a n   ...
#
# [1355 rows x 11 columns]

# %%
X = data[['Area', 'Number_of_rooms', 'Frontage', 'Mortgage', 'Condition','Land_area',"Location_length", 'Location_str']]
y = data['Amount']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('loc', OneHotEncoder(handle_unknown='ignore'), ['Location_str'])
    ],
    remainder='passthrough'
)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(n_estimators=200, learning_rate=0.1, random_state=47))
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=47)

# %%
model.fit(X_train, y_train)
# Out:
# c:\Users\Nariman\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('loc',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Location_str'])])),
#                 ('regressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.1,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=200, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
y_pred = model.predict(X_test)

# %%
results_df = pd.DataFrame({
    'Actual_Amount': y_test.values,
    'Predicted_Amount': y_pred.round(2)
})

print(results_df.head(10))

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"\nMean Absolute Error: {mae:,.2f} AZN")
print(f"R² Score: {r2:.4f}")
# Out:
#    Actual_Amount  Predicted_Amount
# 0         340000     275038.187500
# 1         137000     166193.687500
# 2         368000     330046.062500
# 3         260000     328442.062500
# 4         155000      91222.226562
# 5         285000     144663.171875
# 6          92000     100218.523438
# 7          80000     198304.937500
# 8         275000     303712.718750
# 9          80000      66629.750000
#
# Mean Absolute Error: 52,938.89 AZN
# R² Score: 0.7299
