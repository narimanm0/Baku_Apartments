# %%
import pandas as pd
from config.config import YENI_TIKILI_CSV_FILE

df = pd.read_csv('data/yeni_tikili_data.csv')
df
# Out:
#       Unnamed: 0  Item_id   Amount Currency  \
# 0              0  5165411   408000      AZN
# 1              1  5150136   234000      AZN
# 2              3  5193713   143000      AZN
# 3              4  5193372      500      AZN
# 4              5  4286568       50      AZN
# ...          ...      ...      ...      ...
# 3518        7351  5182620  1350000      AZN
# 3519        7352  4918560   400000      AZN
# 3520        7355  5176082    66000      AZN
# 3521        7356  5116334  4080000      AZN
# 3522        7357  5193021    51000      AZN
#
#                                                Location     Category    Area  \
# 0     ['Grand Hayat Residence', '8 Noyabr m.', 'Yasa...  Yeni tikili  178 m²
# 1     ['Gənclik m.', 'Respublika stadionu', 'Nəriman...  Yeni tikili   65 m²
# 2     ['Ukrayna dairəsi', 'Əhmədli m.', 'Həzi Aslano...  Yeni tikili   75 m²
# 3                        ['20 Yanvar m.', 'Yasamal r.']  Yeni tikili   35 m²
# 4                                          ['Xətai r.']  Yeni tikili   52 m²
# ...                                                 ...          ...     ...
# 3518  ['Port Baku', 'Crescent Bay', 'Cavanşir körpüs...  Yeni tikili  240 m²
# 3519        ['8 Noyabr m.', 'Yasamal r.', 'Yasamal q.']  Yeni tikili  145 m²
# 3520                                                 []  Yeni tikili   45 m²
# 3521  ['Crescent Bay', 'Port Baku', 'Azadlıq meydanı...  Yeni tikili  240 m²
# 3522                       ['Abşeron r.', 'Masazır q.']  Yeni tikili   44 m²
#
#       Number_of_rooms  Frontage  Mortgage  Condition  Land_area  \
# 0                 4.0         1         1          0          0
# 1                 2.0         0         0          1          0
# 2                 3.0         1         0          1          0
# 3                 1.0         0         0          1          0
# 4                 2.0         0         0          1          0
# ...               ...       ...       ...        ...        ...
# 3518              4.0         1         1          1          0
# 3519              3.0         1         0          1          0
# 3520              2.0         1         1          1          0
# 3521              4.0         0         0          0          0
# 3522              2.0         0         0          1          0
#
#       Current_floor  Total_floors
# 0              24.0          27.0
# 1               6.0          18.0
# 2               3.0          17.0
# 3               4.0          20.0
# 4              16.0          19.0
# ...             ...           ...
# 3518           16.0          22.0
# 3519           14.0          27.0
# 3520            9.0          11.0
# 3521           18.0          32.0
# 3522            6.0           6.0
#
# [3523 rows x 14 columns]

# %%
to_delete = ["Unnamed: 0", "Item_id", "Category"]
data = df.drop(to_delete, axis=1)
data
# Out:
#        Amount Currency                                           Location  \
# 0      408000      AZN  ['Grand Hayat Residence', '8 Noyabr m.', 'Yasa...
# 1      234000      AZN  ['Gənclik m.', 'Respublika stadionu', 'Nəriman...
# 2      143000      AZN  ['Ukrayna dairəsi', 'Əhmədli m.', 'Həzi Aslano...
# 3         500      AZN                     ['20 Yanvar m.', 'Yasamal r.']
# 4          50      AZN                                       ['Xətai r.']
# ...       ...      ...                                                ...
# 3518  1350000      AZN  ['Port Baku', 'Crescent Bay', 'Cavanşir körpüs...
# 3519   400000      AZN        ['8 Noyabr m.', 'Yasamal r.', 'Yasamal q.']
# 3520    66000      AZN                                                 []
# 3521  4080000      AZN  ['Crescent Bay', 'Port Baku', 'Azadlıq meydanı...
# 3522    51000      AZN                       ['Abşeron r.', 'Masazır q.']
#
#         Area  Number_of_rooms  Frontage  Mortgage  Condition  Land_area  \
# 0     178 m²              4.0         1         1          0          0
# 1      65 m²              2.0         0         0          1          0
# 2      75 m²              3.0         1         0          1          0
# 3      35 m²              1.0         0         0          1          0
# 4      52 m²              2.0         0         0          1          0
# ...      ...              ...       ...       ...        ...        ...
# 3518  240 m²              4.0         1         1          1          0
# 3519  145 m²              3.0         1         0          1          0
# 3520   45 m²              2.0         1         1          1          0
# 3521  240 m²              4.0         0         0          0          0
# 3522   44 m²              2.0         0         0          1          0
#
#       Current_floor  Total_floors
# 0              24.0          27.0
# 1               6.0          18.0
# 2               3.0          17.0
# 3               4.0          20.0
# 4              16.0          19.0
# ...             ...           ...
# 3518           16.0          22.0
# 3519           14.0          27.0
# 3520            9.0          11.0
# 3521           18.0          32.0
# 3522            6.0           6.0
#
# [3523 rows x 11 columns]

# %%
result = "Yes" if data['Area'].str.endswith('m²').all() else "No"
result
# Out:
# 'Yes'

# %%
data['Area'] = data['Area'].str.replace('m²', '', regex=False)
data
# Out:
#        Amount Currency                                           Location  \
# 0      408000      AZN  ['Grand Hayat Residence', '8 Noyabr m.', 'Yasa...
# 1      234000      AZN  ['Gənclik m.', 'Respublika stadionu', 'Nəriman...
# 2      143000      AZN  ['Ukrayna dairəsi', 'Əhmədli m.', 'Həzi Aslano...
# 3         500      AZN                     ['20 Yanvar m.', 'Yasamal r.']
# 4          50      AZN                                       ['Xətai r.']
# ...       ...      ...                                                ...
# 3518  1350000      AZN  ['Port Baku', 'Crescent Bay', 'Cavanşir körpüs...
# 3519   400000      AZN        ['8 Noyabr m.', 'Yasamal r.', 'Yasamal q.']
# 3520    66000      AZN                                                 []
# 3521  4080000      AZN  ['Crescent Bay', 'Port Baku', 'Azadlıq meydanı...
# 3522    51000      AZN                       ['Abşeron r.', 'Masazır q.']
#
#       Area  Number_of_rooms  Frontage  Mortgage  Condition  Land_area  \
# 0     178               4.0         1         1          0          0
# 1      65               2.0         0         0          1          0
# 2      75               3.0         1         0          1          0
# 3      35               1.0         0         0          1          0
# 4      52               2.0         0         0          1          0
# ...    ...              ...       ...       ...        ...        ...
# 3518  240               4.0         1         1          1          0
# 3519  145               3.0         1         0          1          0
# 3520   45               2.0         1         1          1          0
# 3521  240               4.0         0         0          0          0
# 3522   44               2.0         0         0          1          0
#
#       Current_floor  Total_floors
# 0              24.0          27.0
# 1               6.0          18.0
# 2               3.0          17.0
# 3               4.0          20.0
# 4              16.0          19.0
# ...             ...           ...
# 3518           16.0          22.0
# 3519           14.0          27.0
# 3520            9.0          11.0
# 3521           18.0          32.0
# 3522            6.0           6.0
#
# [3523 rows x 11 columns]

# %%
data.isna().any()
# Out:
# Amount             False
# Currency           False
# Location           False
# Area               False
# Number_of_rooms    False
# Frontage           False
# Mortgage           False
# Condition          False
# Land_area          False
# Current_floor      False
# Total_floors       False
# dtype: bool

# %%
data.columns
# Out:
# Index(['Amount', 'Currency', 'Location', 'Area', 'Number_of_rooms', 'Frontage',
#        'Mortgage', 'Condition', 'Land_area', 'Current_floor', 'Total_floors'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

to_numeric = ['Amount', 'Area', 'Number_of_rooms', 'Current_floor','Total_floors'] 
numeric_data = data[to_numeric]
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
