# %%
import pandas as pd

df = pd.read_json("data/items_data.json")
df

df.to_csv("data/items_data.csv")
df
# Out:
#     item_id   amount currency         Kateqoriya      Sahə Çıxarış  Mərtəbə  \
# 0   5112825   110000      AZN             Torpaq  13.5 sot     var      NaN
# 1   4983218     1800      AZN        Yeni tikili     50 m²     NaN    3 / 6
# 2   4113285   165000      AZN        Yeni tikili     78 m²     var   3 / 16
# 3   4711907      150      AZN  Həyət evi/Bağ evi    500 m²     NaN      NaN
# 4   4038124   345000      AZN  Həyət evi/Bağ evi    140 m²     var      NaN
# 5   5167908   245000      AZN             Obyekt    450 m²     var      NaN
# 6   4687575   444000      AZN  Həyət evi/Bağ evi    250 m²     var      NaN
# 7   4266689   630000      AZN  Həyət evi/Bağ evi    350 m²     var      NaN
# 8   4839041   225000      AZN  Həyət evi/Bağ evi    180 m²     var      NaN
# 9   5107114   540000      AZN  Həyət evi/Bağ evi    250 m²     var      NaN
# 10  5172433      730      AZN        Yeni tikili     60 m²     NaN   8 / 13
# ...
