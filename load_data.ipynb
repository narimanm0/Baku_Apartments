# %%
import pandas as pd
from config.config import OUTPUT_FILE, OUTPUT_CSV_FILE

df = pd.read_json(OUTPUT_FILE)
df

df.to_csv(OUTPUT_CSV_FILE)
df
# Out:
#     item_id  amount currency  \
# 0   5056827    5000      AZN
# 1   4959734  310000      AZN
# 2   5142259  300000      AZN
# 3   5165167  340000      AZN
# 4   5122759  220000      AZN
# ..      ...     ...      ...
# 79  5140712  131000      AZN
# 80  5149053  435000      AZN
# 81  5161334  105000      AZN
# 82  5038503  151000      AZN
# 83  5126935  125000      AZN
#
#                                              location         Kateqoriya  \
# 0   [Rəssamlıq Akademiyası, Nəriman Nərimanov m., ...             Obyekt
# 1                                                  []        Yeni tikili
# 2                       [Memar Əcəmi m., Binəqədi r.]             Obyekt
# 3                              [Xəzər r., Şüvəlan q.]  Həyət evi/Bağ evi
# 4   [Azadlıq Prospekti m., Binəqədi r., 8-ci mikro...       Köhnə tikili
# ..                                                ...                ...
# 79                           [Abşeron r., Novxanı q.]  Həyət evi/Bağ evi
# 80                                       [Sabunçu r.]        Yeni tikili
# 81                           [Suraxanı r., Hövsan q.]        Yeni tikili
# 82                         [20 Yanvar m., Yasamal r.]        Yeni tikili
# 83                           [Abşeron r., Novxanı q.]  Həyət evi/Bağ evi
#
#         Sahə   Təmir  Mərtəbə  Otaq sayı Çıxarış Torpaq sahəsi İpoteka
# 0     500 m²     var      NaN        NaN     NaN           NaN     NaN
# 1     150 m²     var   6 / 14        4.0     var           NaN     NaN
# 2      50 m²     var      NaN        NaN     var           NaN     NaN
# 3     250 m²     var      NaN        5.0     var         6 sot     NaN
# 4      85 m²     var    2 / 9        3.0     var           NaN     NaN
# ..       ...     ...      ...        ...     ...           ...     ...
# 79    200 m²     var      NaN        5.0     var       4.8 sot     var
# 80  133.4 m²  yoxdur    4 / 6        3.0  yoxdur           NaN     var
# 81     90 m²     var   9 / 12        3.0     var           NaN     var
# 82     52 m²     var  10 / 18        2.0     var           NaN     var
# 83    210 m²     var      NaN        5.0     var        11 sot     NaN
#
# [84 rows x 12 columns]
