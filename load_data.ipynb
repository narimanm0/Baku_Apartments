# %%
import pandas as pd

df = pd.read_json("data/items_data.json")
df

df.to_csv("data/items_data.csv")
df
# Out:
#     item_id  amount currency  \
# 0   4959734  310000      AZN
# 1   5184413     900      AZN
# 2   5165167  340000      AZN
# 3   5122759  220000      AZN
# 4   4802446  225000      AZN
# ..      ...     ...      ...
# 79  5084859  119500      AZN
# 80  5119065  390000      AZN
# 81  5149053  435000      AZN
# 82  5161334  105000      AZN
# 83  5038503  151000      AZN
#
#                                              location         Kateqoriya  \
# 0                                                  []        Yeni tikili
# 1                           [20 Yanvar m., Nəsimi r.]        Yeni tikili
# 2                              [Xəzər r., Şüvəlan q.]  Həyət evi/Bağ evi
# 3   [Azadlıq Prospekti m., Binəqədi r., 8-ci mikro...       Köhnə tikili
# 4                                                  []        Yeni tikili
# ..                                                ...                ...
# 79  [Azadlıq Prospekti m., Binəqədi r., 7-ci mikro...       Köhnə tikili
# ...
