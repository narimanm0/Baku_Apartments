# %%
import pandas as pd
from config.config import OUTPUT_FILE, OUTPUT_CSV_FILE

df = pd.read_json(OUTPUT_FILE)
df

df.to_csv(OUTPUT_CSV_FILE)
df
# Out:
#       item_id   amount currency  \
# 0     5165411   408000      AZN
# 1     5150136   234000      AZN
# 2     5117823   329000      AZN
# 3     5193713   143000      AZN
# 4     5193372      500      AZN
# ...       ...      ...      ...
# 7354  5010680      599      AZN
# 7355  5176082    66000      AZN
# 7356  5116334  4080000      AZN
# 7357  5193021    51000      AZN
# 7358  5057528     5000      AZN
#
#                                                location         Kateqoriya  \
# 0     [Grand Hayat Residence, 8 Noyabr m., Yasamal r...        Yeni tikili
# 1       [Gənclik m., Respublika stadionu, Nərimanov r.]        Yeni tikili
# 2                               [Xəzər r., Mərdəkan q.]             Torpaq
# 3     [Ukrayna dairəsi, Əhmədli m., Həzi Aslanov m.,...        Yeni tikili
# 4                            [20 Yanvar m., Yasamal r.]        Yeni tikili
# ...                                                 ...                ...
# 7354                   [Xalqlar Dostluğu m., Nizami r.]       Köhnə tikili
# 7355                                                 []        Yeni tikili
# 7356  [Crescent Bay, Port Baku, Azadlıq meydanı, Nəs...        Yeni tikili
# 7357                           [Abşeron r., Masazır q.]        Yeni tikili
# 7358                            [Sabunçu r., Bilgəh q.]  Həyət evi/Bağ evi
#
#       Mərtəbə    Sahə  Otaq sayı Çıxarış İpoteka   Təmir Torpaq sahəsi  \
# 0     24 / 27  178 m²        4.0     var     var  yoxdur           NaN
# 1      6 / 18   65 m²        2.0  yoxdur     NaN     var           NaN
# 2         NaN  19 sot        NaN     var     NaN     NaN           NaN
# 3      3 / 17   75 m²        3.0     var     NaN     var           NaN
# 4      4 / 20   35 m²        1.0     NaN     NaN     var           NaN
# ...       ...     ...        ...     ...     ...     ...           ...
# 7354    6 / 9   75 m²        3.0     NaN     NaN     var           NaN
# 7355   9 / 11   45 m²        2.0     var     var     var           NaN
# 7356  18 / 32  240 m²        4.0  yoxdur     NaN  yoxdur           NaN
# 7357    6 / 6   44 m²        2.0  yoxdur     NaN     var           NaN
# 7358      NaN  600 m²        6.0     NaN     NaN     var        30 sot
#
#      Binanın növü
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 7354          NaN
# 7355          NaN
# 7356          NaN
# 7357          NaN
# 7358          NaN
#
# [7359 rows x 13 columns]
